# %%
import math

#defining function to calculate volume of speheres given their radius
def compute_volume_sphere(radius):
    return (4/3) * math.pi * (radius**3)

#using the figures from NASA as the radius of the sola system 
Solar_System_radius = 4.545 * 1500000000
Solar_System_volume= compute_volume_sphere(Solar_System_radius)
Chesnut_radius = 3/2 *0.01
Chesnut_volume_M3 =compute_volume_sphere(Chesnut_radius)

Current_time = 0
Minutes=[]
volumes =[]
current_chesnut_volume = Chesnut_volume_M3


# Program to calculate the time taken
while current_chesnut_volume < Solar_System:
    volumes.append(current_chesnut_volume)
    current_chesnut_volume*=2
    Minutes.append(Current_time)
    Current_time +=5
    
print(f"it will take {Minutes[-1]} minutes to cover the solar system")
# Out:
# it will take 230 minutes to cover the solar system

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#plotting a graph to visualize the output of the doubling rate of chesnut buns with time.
plt.title(" Doubling rate of chesnut buns with time", fontsize=14, color = "blue")
plt.xlabel("Volume", color="Brown", fontsize=12)
plt.ylabel("Time", color="Brown" , fontsize=12)
plt.plot(Minutes, volumes, color ='Blue')  
plt.show()
